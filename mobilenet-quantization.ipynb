# %% [markdown]
# # MobileNetV2 for Age and Gender Recognition

# %% [markdown]
# ## Load the Keras model from the saved file

# %%
import tensorflow as tf
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy

# Load the model with custom objects to resolve the loss functions
model = tf.keras.models.load_model(
    'Original_MobileNet_Age_Gender.h5',
    custom_objects={
        'mse': MeanSquaredError(),
        'binary_crossentropy': BinaryCrossentropy()
    }
)

print("Model loaded successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!

# %% [markdown]
# ## Inference Time and Memory Usage on CPU

# %%
import numpy as np
import time

# Generate dummy data 
dummy_data = np.random.rand(20, 128, 128, 3).astype('float32')

# Measure inference time on CPU
start_time = time.time()
_ = model.predict(dummy_data)
end_time = time.time()

# Calculate and print the average inference time per sample
inference_time = (end_time - start_time) / len(dummy_data)
print(f"Average inference time per sample: {inference_time:.6f} seconds")

# Calculate memory usage
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
memory_usage_bytes = trainable_params * 4  # 4 bytes per float32
memory_usage_mb = memory_usage_bytes / (1024 ** 2)  # Convert to MB
print(f"Model memory usage: {memory_usage_mb:.2f} MB")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Average inference time per sample: 0.049641 seconds
# Model memory usage: 9.74 MB

# %% [markdown]
# ## Export the model in SavedModel format

# %%
model.export("mobilenet_age_gender_savedmodel_format")
# Out:
# INFO:tensorflow:Assets written to: mobilenet_savedmodel_format/assets
# INFO:tensorflow:Assets written to: mobilenet_savedmodel_format/assets
# Saved artifact at 'mobilenet_savedmodel_format'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   List[TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)]
# Captures:
#   6097888912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101992464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101992656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101992272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101991696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101993616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101994384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101993232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101994192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101992848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101995536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101996304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101995152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101996112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101994768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101997456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101998224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101997072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101998032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101996688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101999376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102000144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101998992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101999952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6101998608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102001296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102002064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102000912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102001872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102000528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102003216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102003984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102002832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102003792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102002448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102005136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102005904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102004752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102005712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102004368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102007056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102253840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102254032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102007440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102007632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102254800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102255568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102254416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102255376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102254224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102256720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102257488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102256336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102257296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102255952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102258640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102259408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102258256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102259216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102257872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102260560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102261328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102260176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102261136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102259792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102262480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102263248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102262096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102263056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102261712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102264400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102265168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102264016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102264976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102263632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102266320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102267088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102265936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102266896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102265552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102268240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102269008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102268624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102268816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102267472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102434064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102434832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102435024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102434640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102434256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102435984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102436752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102435600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102436560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102435216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102437904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102438672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102437520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102438480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102437136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102439824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102440592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102439440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102440400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102439056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102441744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102442512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102441360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102442320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102440976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102443664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102444432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102443280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102444240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102442896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102445584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102446352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102445200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102446160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102444816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102447504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102448272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102447120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102448080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102446736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102449424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102679632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102680016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102449808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102450000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102680784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102681552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102680400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102681360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102680208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102682704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102683472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102682320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102683280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102681936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102684624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102685392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102684240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102685200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102683856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102686544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102687312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102686160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102687120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102685776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102688464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102689232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102688080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102689040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102687696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102690384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102691152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102690000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102690960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102689616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102692304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102693072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102691920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102692880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102691536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102694224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102694992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102694608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102694800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102693456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102925584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102926352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102926544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102926160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102925776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102927504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102928272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102927120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102928080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102926736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102929424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102930192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102929040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102930000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102928656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102931344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102932112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102930960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102931920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102930576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102933264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102934032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102932880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102933840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102932496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102935184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102935952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102934800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102935760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102934416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102937104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102937872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102936720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102937680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102936336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102939024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102939792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102938640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102939600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102938256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102940944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103138576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103138768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102941328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6102941520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103139536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103140304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103139152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103140112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103138960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103141456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103142224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103141072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103142032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103140688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103143376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103144144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103142992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103143952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103142608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103145296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103146064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103144912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103145872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103144528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103147216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103147984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103146832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103147792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103146448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103149136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103149904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103148752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103149712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103148368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103151056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103151824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103150672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103151632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103150288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103152976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103153744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103153360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103153552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103152208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103335184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103335952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103336144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103335760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103335376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103337488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103338448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103337104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103337680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103339024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103339984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103338256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   6103339216: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# ## Save the Quantized TensorFlow Lite model

# %%
# Load the model from the saved directory and convert it to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_saved_model('mobilenet_savedmodel_format')

# Apply quantization optimizations
converter.optimizations = [tf.lite.Optimize.DEFAULT]

# Convert the model to TensorFlow Lite format
tflite_model = converter.convert()

# Save the quantized TensorFlow Lite model
with open('Quantized_MobileNet_Age_Gender.tflite', 'wb') as f:
    f.write(tflite_model)

print("Quantized model saved as Quantized_MobileNet_Age_Gender.tflite.")
# Out:
# Quantized model saved as Quantized_MobileNet_Age_Gender.tflite.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1728743858.119349 2610487 tf_tfl_flatbuffer_helpers.cc:390] Ignored output_format.
# W0000 00:00:1728743858.119381 2610487 tf_tfl_flatbuffer_helpers.cc:393] Ignored drop_control_dependency.
# 2024-10-12 20:07:38.119973: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: mobilenet_savedmodel_format
# 2024-10-12 20:07:38.128968: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-10-12 20:07:38.128977: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: mobilenet_savedmodel_format
# 2024-10-12 20:07:38.277622: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# 2024-10-12 20:07:38.292665: I tensorflow/cc/saved_model/loader.cc:234] Restoring SavedModel bundle.
# 2024-10-12 20:07:38.846405: I tensorflow/cc/saved_model/loader.cc:218] Running initialization op on SavedModel bundle at path: mobilenet_savedmodel_format
# 2024-10-12 20:07:38.998830: I tensorflow/cc/saved_model/loader.cc:317] SavedModel load for tags { serve }; Status: success: OK. Took 878857 microseconds.
# 2024-10-12 20:07:39.112377: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %% [markdown]
# # MobileNetV2 for Expression Recognition

# %% [markdown]
# ## Load the Keras model from the saved file

# %%
import tensorflow as tf

model = tf.keras.models.load_model('Original_MobileNet_Expression.h5')

print("Model loaded successfully!")
# Out:
# 2024-10-13 19:43:45.831537: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!

# %% [markdown]
# ## Export the model in SavedModel format

# %%
model.export("mobilenet_expression_savedmodel_format")
# Out:
# INFO:tensorflow:Assets written to: mobilenet_expression_savedmodel_format/assets
# INFO:tensorflow:Assets written to: mobilenet_expression_savedmodel_format/assets
# Saved artifact at 'mobilenet_expression_savedmodel_format'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 1), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   5971406544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971407120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971406736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971407888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971408080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971407312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971408272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971408464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971407696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971408848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971410384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975900816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975900624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971409424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5971410576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975901008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975901968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975902352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975901776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975902160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975903888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975904656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975903504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975904464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975903120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975905808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975906576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975905424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975906384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975905040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975907728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975908496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975907344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975908304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975906960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975909840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975910224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975908880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975910032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975909648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975911568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975911952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975910608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975911760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975911376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975913104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975913872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975912720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975913680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975912336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975915024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975915408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975914640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975915600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5975914256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5976130192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5976130768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5976129616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5976130576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5976130000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5976131920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5